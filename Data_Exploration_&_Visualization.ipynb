# %% [markdown]
# <a href="https://colab.research.google.com/github/Seb-GJ/B1-Programacion-con-Javascript-2020/blob/master/Data_Exploration_%26_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("shivanirana63/food-demand-forecasting")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /root/.cache/kagglehub/datasets/shivanirana63/food-demand-forecasting/versions/1

# %%
import pandas as pd

# %%
import os

# Listar archivos en el directorio
print(os.listdir(path))
# Out:
# ['train', 'sample_submission.xls', 'test.xls']

# %%
train_path = os.path.join(path,'train')
files_in_train = os.listdir(train_path)

print("Archivos en la carpeta 'train':", files_in_train)
# Out:
# Archivos en la carpeta 'train': ['fulfilment_center_info.csv', 'meal_info.csv', 'train.csv']

# %%
file_path = os.path.join(train_path,'train.csv')
df_weekly = pd.read_csv(file_path)

# %%
df_weekly.shape
# Out:
# (456548, 9)

# %%
df_weekly.head(34)
# Out:
#          id  week  center_id  meal_id  checkout_price  base_price  \
# 0   1379560     1         55     1885          136.83      152.29
# 1   1466964     1         55     1993          136.83      135.83
# 2   1346989     1         55     2539          134.86      135.86
# 3   1338232     1         55     2139          339.50      437.53
# 4   1448490     1         55     2631          243.50      242.50
# 5   1270037     1         55     1248          251.23      252.23
# 6   1191377     1         55     1778          183.36      184.36
# 7   1499955     1         55     1062          182.36      183.36
# 8   1025244     1         55     2707          193.06      192.06
# 9   1054194     1         55     1207          325.92      384.18
# 10  1469367     1         55     1230          323.01      390.00
# 11  1029333     1         55     2322          322.07      388.00
# 12  1446016     1         55     2290          311.43      310.43
# ...

# %%
file_path1 = os.path.join(train_path,'fulfilment_center_info.csv')
df_fulfill = pd.read_csv(file_path1)

# %%
df_fulfill.head()
# Out:
#    center_id  city_code  region_code center_type  op_area
# 0         11        679           56      TYPE_A      3.7
# 1         13        590           56      TYPE_B      6.7
# 2        124        590           56      TYPE_C      4.0
# 3         66        648           34      TYPE_A      4.1
# 4         94        632           34      TYPE_C      3.6

# %%
df_fulfill['center_id'].unique()
# Out:
# array([ 11,  13, 124,  66,  94,  64, 129, 139,  88, 143, 101,  86,  32,
#        149, 152,  92,  27,  14,  26, 104,  77,  23,  97, 146, 113, 145,
#         80,  55, 186,  99,  91,  20, 106,  81,  73,  29,  43, 102,  61,
#         50,  83,  57, 126, 177,  67, 174,  59,  58,  65,  39, 132,  89,
#        162,  75,  72,  41,  10, 110,  52,  93,  74,  34, 137, 153,  24,
#        109, 108,  36, 157,  17, 161,  42,  53,  30,  76,  68,  51])

# %%
file_path2= os.path.join(train_path,'meal_info.csv')
df_meal = pd.read_csv(file_path2)

# %%
df_meal.head()
# Out:
#    meal_id   category cuisine
# 0     1885  Beverages    Thai
# 1     1993  Beverages    Thai
# 2     2539  Beverages    Thai
# 3     1248  Beverages  Indian
# 4     2631  Beverages  Indian

# %%
df_meal['category'].unique()
# Out:
# array(['Beverages', 'Extras', 'Soup', 'Other Snacks', 'Salad',
#        'Rice Bowl', 'Starters', 'Sandwich', 'Pasta', 'Desert', 'Biryani',
#        'Pizza', 'Fish', 'Seafood'], dtype=object)

# %%
df_meal['cuisine'].unique()
# Out:
# array(['Thai', 'Indian', 'Italian', 'Continental'], dtype=object)

# %% [markdown]
# **Ligaremos el Center Id del Weekly con el del fullfillment y el meal_id del meal con el del Weekly**

# %%
import csv,sqlite3

# %%
# !pip install ipython-sql --upgrade
# !pip install prettytable --upgrade

# %%
con = sqlite3.connect('store.db')
cur = con.cursor()

# %%
# %reload_ext sql
# %sql sqlite:///store.db
# %config SqlMagic.style = 'DEFAULT'

# %%
df_weekly.to_sql('Weekly', con, if_exists='replace', index=False)
df_fulfill.to_sql('Fulfill', con, if_exists='replace', index=False)
df_meal.to_sql('Meal', con, if_exists='replace', index=False)
# Out:
# 51
